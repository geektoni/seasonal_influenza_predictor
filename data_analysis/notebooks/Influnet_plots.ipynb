# %% [markdown]
# # Data Visualization

# %% [markdown]
# The script `plot_generator.py` takes as arguments a list of Influnet's csv files and plots them to show the ILI levels on each monitored period. The generated plot has on the X-axis the week numbers and on the Y-axis the ILI incidence rate per 1000 persons. Below you can find for each year a dedicated plot.

# %%
# %pylab inline

# %%
pylab.rcParams['figure.figsize'] = (20, 10)

# %% [markdown]
# Below there is a summative plot that use all the Influnet's data:

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2006_2007.csv ../../data/influnet/csv/tabula-2007_2008.csv ../../data/influnet/csv/tabula-2008_2009.csv ../../data/influnet/csv/tabula-2009_2010.csv  ../../data/influnet/csv/tabula-2010_2011.csv ../../data/influnet/csv/tabula-2011_2012.csv ../../data/influnet/csv/tabula-2012_2013.csv ../../data/influnet/csv/tabula-2013_2014.csv ../../data/influnet/csv/tabula-2014_2015.csv ../../data/influnet/csv/tabula-2015_2016.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2006_2007.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2008_2009.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2011_2012.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2012_2013.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2013_2014.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2014_2015.csv

# %%
# %run ../plot_generator.py ../../data/influnet/csv/tabula-2015_2016.csv
